-- %% [markdown]
-- # SQL Part 1 Studio
--
-- ### Let's practice your SQL quering skills!  For each question, work along in the notebook adding your query and answering the questions.
--
-- ### **DataSet**
--
-- ### <span style="font-size: 14px; font-family: -apple-system, BlinkMacSystemFont, sans-serif;">We will be using the Goodbooks-10k dataset from the exercises in the prep work.&nbsp; Feel free reference your notebook.</span>
--
-- - The dataset can be found here: [goodbooks-10k](https://www.kaggle.com/zygmunt/goodbooks-10k)
-- - You can access the **BooksDB** in the Launchcode server.
--
-- ### **Business Issue**
--
-- You are an employee at a small independet bookstore and you have been tasked to increase sales.  You decide to use the BooksDB to find bookss and themes to highlight in fun promotions throughout each month.  We will be starting with March and then you will have a chance to explore another month of your choosing.  We want to come up with a list of at least 3 events/ promotions to run each month.  If you are looking for ideas to include in your promotions:
--
-- - [https://www.calendarr.com/united-states/calendar-2022/](https://www.calendarr.com/united-states/calendar-2022/)
-- - [https://www.holidayinsights.com/moreholidays/](https://www.holidayinsights.com/moreholidays/)
--     - Click on a month and it will take you to a more detailed page

-- %% [markdown]
-- ## A. March - Womans History Month, Dr Seuss Day(3/2), National Pie Day3/14, St Patricks Day (3/17), James Patterson(3/22)

-- %% [markdown]
-- Event 1: Womans History Month
--
-- Goal: Highlight Popular Womans Authors and Issues

-- %%
-- SOLUTION
-- Query to look at tags to see which ones may be helpful
SELECT TOP 1000 * 
   FROM BooksDB.dbo.tags
   WHERE tag_name LIKE '%woman' OR tag_name LIKE 'woman%' OR tag_name LIKE '%woman%'
-- Out:
-- (24 rows affected)
-- Total execution time: 00:00:00.365
-- <table><tr><th>tag_id</th><th>tag_name</th></tr><tr><td>937</td><td>21-books-every-woman-should-read</td></tr><tr><td>1386</td><td>a-woman-after-god-s-own-heart</td></tr><tr><td>1387</td><td>a-woman-after-gods-own-heart</td></tr><tr><td>4006</td><td>batwoman</td></tr><tr><td>4455</td><td>biblical-womanhood</td></tr><tr><td>4729</td><td>black-ops-woman-team-cia-sean-case</td></tr><tr><td>5132</td><td>books-every-woman-should-read</td></tr><tr><td>7194</td><td>christian-woman</td></tr><tr><td>10986</td><td>every-woman-should-read</td></tr><tr><td>19038</td><td>man-woman</td></tr><tr><td>19757</td><td>memorable-woman-characters</td></tr><tr><td>22269</td><td>older-man-younger-woman</td></tr><tr><td>22270</td><td>older-woman</td></tr><tr><td>22271</td><td>older-woman-younger-man</td></tr><tr><td>23671</td><td>pioneer-woman</td></tr><tr><td>23891</td><td>policewoman-potential-victim</td></tr><tr><td>32679</td><td>woman-author</td></tr><tr><td>32680</td><td>woman-s-fiction</td></tr><tr><td>32681</td><td>woman-s-murder-club</td></tr><tr><td>32682</td><td>woman-trans-agender-authors</td></tr><tr><td>32683</td><td>womanhood</td></tr><tr><td>32684</td><td>womans-literature</td></tr><tr><td>32685</td><td>womans-murder-club</td></tr><tr><td>32740</td><td>wonder-woman</td></tr></table>

-- %% [markdown]
-- Decide I want to explore the following tags:
--
-- line 17 tag\_id is woman-author, 32679
--
-- line 20 tag\_id is woman-trans-agender-author, 32682
--
-- line 21 tag\_id is womanhood, 32683
--
-- Decide I want to return the top 10 rated books with each tag to highlight

-- %%
SELECT TOP 10(title)
FROM BooksDB.dbo.books
WHERE

-- %% [markdown]
-- QUESTION 3: Count the number of books where the original\_publication\_year is earlier than 1800.

-- %%
-- SOLUTION
SELECT COUNT(*)
FROM BooksDB.dbo.books
WHERE original_publication_year < 1800
-- Out:
-- (1 row affected)
-- Total execution time: 00:00:00.061
-- <table><tr><th>(No column name)</th></tr><tr><td>125</td></tr></table>

-- %% [markdown]
-- QUESTION 4: Create a query that displays distinct authors from the table.

-- %%
-- SOLUTION
SELECT DISTINCT (authors)
FROM BooksDB.dbo.books
-- Out:
-- (4664 rows affected)
-- Total execution time: 00:00:00.410
-- <table><tr><th>authors</th></tr><tr><td>A. Manette Ansay</td></tr><tr><td>A. Meredith Walters</td></tr><tr><td>A.A. Milne, Ernest H. Shepard</td></tr><tr><td>A.C. Gaughen</td></tr><tr><td>A.G. Howard</td></tr><tr><td>A.G. Riddle</td></tr><tr><td>A.J. Banner</td></tr><tr><td>A.J. Jacobs</td></tr><tr><td>A.L. Singer, Walt Disney Company</td></tr><tr><td>A.M. Homes</td></tr><tr><td>A.N. Roquelaure, Anne Rice</td></tr><tr><td>A.P.J. Abdul Kalam, Arun Tiwari</td></tr><tr><td>A.S. Byatt</td></tr><tr><td>A.S. King</td></tr><tr><td>A.S.A. Harrison</td></tr><tr><td>A.W. Tozer</td></tr><tr><td>Abbi Glines</td></tr><tr><td>Abigail Haas, Abby McDonald</td></tr><tr><td>Abraham Verghese</td></tr><tr><td>Adam Gidwitz</td></tr><tr><td>Adam Gopnik</td></tr><tr><td>Adam Hochschild</td></tr><tr><td>Adam Johnson</td></tr><tr><td>Adam M. Grant</td></tr><tr><td>Adam Makos, Larry Alexander</td></tr><tr><td>Adam Mansbach, Ricardo Cortés</td></tr><tr><td>Adam Smith</td></tr><tr><td>Addison Moore</td></tr><tr><td>Adele Faber, Elaine Mazlish, Kimberly Ann Coe</td></tr><tr><td>Adeline Yen Mah</td></tr><tr><td>Adelle Waldman</td></tr><tr><td>Adolf Hitler</td></tr><tr><td>Adolfo Bioy Casares, Suzanne Jill Levine, Jorge Luis Borges, Ruth L.C. Simms, Norah Borges de Torre</td></tr><tr><td>Adrian Conan Doyle, John Dickson Carr</td></tr><tr><td>Adrian Nicole LeBlanc</td></tr><tr><td>Adriana Trigiani</td></tr><tr><td>Aeschylus, Judith Affleck, Philip de May, Patricia E. Easterling, John     Harrison</td></tr><tr><td>Aeschylus, Robert Fagles, William Bedell Stanford</td></tr><tr><td>Aesop, Laura Harris, Laura Gibbs</td></tr><tr><td>Agatha Christie</td></tr><tr><td>Agatha Christie, Hugh Fraser</td></tr><tr><td>Agatha Christie, Robin Bailey</td></tr><tr><td>Agatha Christie, Ροζίτα Σώκου</td></tr><tr><td>Ahmad Fuadi</td></tr><tr><td>Ai Yazawa</td></tr><tr><td>Aimee Bender</td></tr><tr><td>Aimee Carter</td></tr><tr><td>Akira Amano, JN Productions, Frances E. Wall</td></tr><tr><td>Akira Toriyama</td></tr><tr><td>Al Dempster, Milt Banta, Golden Books, Walt Disney Company</td></tr><tr><td>Al Franken</td></tr><tr><td>Al Perkins, Eric Gurney</td></tr><tr><td>Al Ries, Jack Trout</td></tr><tr><td>Alaa Al Aswany, علاء الأسواني</td></tr><tr><td>Alain de Botton</td></tr><tr><td>Alan    Richardson, Karen Tack</td></tr><tr><td>Alan Bennett</td></tr><tr><td>Alan Bradley</td></tr><tr><td>Alan Brennert</td></tr><tr><td>Alan Cumming</td></tr><tr><td>Alan Dean Foster</td></tr><tr><td>Alan Dean Foster, George Lucas</td></tr><tr><td>Alan Dean Foster, Lawrence Kasdan, J.J. Abrams, Michael Arndt</td></tr><tr><td>Alan Hollinghurst</td></tr><tr><td>Alan Lee, Ian McKellen</td></tr><tr><td>Alan Lightman</td></tr><tr><td>Alan Moore, Brian Bolland, Tim Sale</td></tr><tr><td>Alan Moore, Curt Swan, George Pérez, Kurt Schaffenberger</td></tr><tr><td>Alan Moore, Dave Gibbons, John Higgins</td></tr><tr><td>Alan Moore, David   Lloyd</td></tr><tr><td>Alan Moore, Eddie Campbell, Pete Mullins</td></tr><tr><td>Alan Moore, Kevin O'Neill</td></tr><tr><td>Alan Moore, Stephen R. Bissette, John Totleben, Rick Veitch, Ramsey Campbell</td></tr><tr><td>Alan Paton</td></tr><tr><td>Alan W. Watts</td></tr><tr><td>Alan Weisman</td></tr><tr><td>Alastair Reynolds</td></tr><tr><td>Albert Camus, Justin O'Brien</td></tr><tr><td>Albert Camus, Matthew    Ward</td></tr><tr><td>Albert Camus, Stuart Gilbert</td></tr><tr><td>Albert Einstein, Nigel Calder, Robert W. Lawson</td></tr><tr><td>Aldo Leopold</td></tr><tr><td>Aldous Huxley</td></tr><tr><td>Aldous Huxley, Christopher Hitchens</td></tr><tr><td>Aleatha Romig</td></tr><tr><td>Aleksandr Griboyedov, Александр Сергеевич Грибоедов</td></tr><tr><td>Aleksandr Solzhenitsyn, Edward E. Ericson Jr.</td></tr><tr><td>Aleksandr Solzhenitsyn, H.T. Willetts</td></tr><tr><td>Alessandra Torre</td></tr><tr><td>Alessandro Baricco</td></tr><tr><td>Alex   Sanchez</td></tr><tr><td>Alex  Ross</td></tr><tr><td>Alex Berenson</td></tr><tr><td>Alex Flinn</td></tr><tr><td>Alex Garland</td></tr><tr ...

-- %% [markdown]
-- QUESTION 5: Create a query that displays a count of all the books that contain a language code for English.  This could be represented in the table as "eng" or "en-".

-- %%
-- Solution

-- SELECT COUNT(*)
   -- FROM BooksDB.dbo.books
   -- WHERE language_code LIKE 'en%';

-- rows: 8730
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.052

-- %% [markdown]
-- QUESTION 6: Create a query to check how many original titles were written during World War I era (1914-1921).

-- %%
-- Solution
-- --SELECT original_title
    -- FROM BooksDB.dbo.books
    -- WHERE original_publication_year BETWEEN 1914 AND 1921;
    -- WHERE original_publication_year IN(1914,1915,1916,1917,1918,1919,1920,1921);

-- 39 rows
-- Out:
-- Commands completed successfully.
-- Total execution time: 00:00:00.048

-- %% [markdown]
-- # Part 2 Choose Another Month
--
-- Choose another month and plan at least 3 events / promotions and answer the following questions.
--
-- Which month did you choose?
--
-- What 3 events / promotions are you highlighting?
--
-- > 1.
--
-- > 2.
--
-- > 3.

-- %% [markdown]
-- # Part 3. Summarize your Work
--
-- For each event write at least one query to support your choice and record you thoughts as to why you used the paticlular query.

-- %%
-- Event 1

-- %%
-- Event 2

-- %%
-- Event 3
